# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
pwd
# Out:
# 'c:\\Users\\Kevi6\\Documents\\ddico9\\projects\\group4_eda\\data'

# %%
helth_df = pd.read_csv("data.csv")
helth_df
# Out:
#       Country Name Country Code  \
# 0       Arab World          ARB
# 1       Arab World          ARB
# 2       Arab World          ARB
# 3       Arab World          ARB
# 4       Arab World          ARB
# ...            ...          ...
# 89005     Zimbabwe          ZWE
# 89006     Zimbabwe          ZWE
# 89007     Zimbabwe          ZWE
# 89008     Zimbabwe          ZWE
# 89009     Zimbabwe          ZWE
#
#                                           Indicator Name     Indicator Code  \
# 0      % of females ages 15-49 having comprehensive c...  SH.HIV.KNOW.FE.ZS
# 1      % of males ages 15-49 having comprehensive cor...  SH.HIV.KNOW.MA.ZS
# 2      Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 3      Adults (ages 15+) and children (0-14 years) li...        SH.HIV.TOTL
# 4      Adults (ages 15+) and children (ages 0-14) new...     SH.HIV.INCD.TL
# ...                                                  ...                ...
# ...

# %%
helth_df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', 'Unnamed: 60'],
#       dtype='object')

# %%
for col in helth_df.columns:
    for letter in col:
        if letter[0] == '1' or letter[0] == '20':
# Out:
# 1960
# 1961
# 1961
# 1962
# 1963
# 1964
# 1965
# 1966
# 1967
# 1968
# 1969
# 1970
# 1971
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# 1978
# 1979
# 1980
# 1981
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2001
# 2010
# 2011
# 2011
# 2012
# 2013
# 2014
# 2015

# %%
total_countries =helth_df.groupby(['Indicator Name']).sum(["1960"]).sort_values(["1960"],ascending=False)
total_countries = total_countries.T
total_countries
# Out:
# Indicator Name  Population, total  Rural population  \
# 1960                 2.574921e+10      1.753990e+10
# 1961                 2.609149e+10      1.763801e+10
# 1962                 2.654493e+10      1.782432e+10
# 1963                 2.710655e+10      1.809235e+10
# 1964                 2.767316e+10      1.835751e+10
# 1965                 2.825228e+10      1.867713e+10
# 1966                 2.886096e+10      1.902021e+10
# 1967                 2.946726e+10      1.935622e+10
# 1968                 3.008323e+10      1.969872e+10
# 1969                 3.073153e+10      2.005885e+10
# 1970                 3.138766e+10      2.042561e+10
# 1971                 3.206175e+10      2.080129e+10
# 1972                 3.273155e+10      2.116274e+10
# 1973                 3.339529e+10      2.150942e+10
# 1974                 3.406140e+10      2.184074e+10
# 1975                 3.471419e+10      2.217795e+10
# 1976                 3.535348e+10      2.249244e+10
# ...

# %%
#total_countries.plot.scatter(x=total_countries['Literacy rate, adult male (% of males ages 15 and above)'],
#                             y=total_countries[14])


# create a figure and axis
fig, ax = plt.subplots()

# scatter the sepal_length against the sepal_width
ax.scatter(total_countries['Literacy rate, adult male (% of males ages 15 and above)'], total_countries['% of males ages 15-49 having comprehensive correct knowledge about HIV (2 prevent ways and reject 3 misconceptions)'],s=0.00000001*total_countries['Population, male'])
# set a title and labels
ax.set_title('How much do men know HIV')
ax.set_xlabel('Literacy rate in males')
ax.set_ylabel('knowledge about HIV in males')
# Out:
# Text(0, 0.5, 'knowledge about HIV in males')

# %%
sn.lineplot(data=total_countries['Literacy rate, adult male (% of males ages 15 and above)'])
# Out:
# c:\Users\Kevi6\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Kevi6\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Literacy rate, adult male (% of males ages 15 and above)'>

# %%
sn.lineplot(data=total_countries['% of males ages 15-49 having comprehensive correct knowledge about HIV (2 prevent ways and reject 3 misconceptions)'])
# Out:
# c:\Users\Kevi6\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Kevi6\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='% of males ages 15-49 having comprehensive correct knowledge about HIV (2 prevent ways and reject 3 misconceptions)'>

# %%
corr_matrix= helth_df.corr(numeric_only=True)

## Heatmap showing the highest/lowest rate of each of the five crimes
plt.figure(figsize=(12, 9))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 5
#       3 ## Heatmap showing the highest/lowest rate of each of the five crimes
#       4 plt.figure(figsize=(12, 9))
# ----> 5 sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
#       6 plt.title('Correlation Heatmap')
#       7 plt.show()
#
# NameError: name 'sns' is not defined
